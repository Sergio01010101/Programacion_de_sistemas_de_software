# %% [markdown]
# <a href="https://colab.research.google.com/github/Sergio01010101/Programacion_de_sistemas_de_software/blob/main/clase3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile hola_mundo.c
# #include <stdio.h>

# %%
# %%writefile practice.c
# #include <stdio.h>
#
# int main(){
#   unsigned char numero1 = 45;
#   signed char numero2 = -12;
#
#   unsigned char opr_and = numero1 & numero2;
#
#   unsigned char opr_or = numero1 | numero2;
#
#   printf("el valor de opr_and es: %d\n", opr_and);
#
#   printf("el valor de opr_or es: %d", opr_or);
#
#   return 0;
# }
# Out:
# Overwriting practice.c

# %%
# !gcc practice.c -o practice && ./practice
# Out:
# el valor de opr_and es: 36
# el valor de opr_or es:253

# %%
# %%writefile desplazamientos.c
# #include <stdio.h>
#
# int main (){
#
# }
